# %%
import logging
import os
from importlib import import_module

import click
import datacube
import fsspec
import geopandas as gpd
from rasterio.errors import RasterioIOError

from deafrica_conflux.cli.logs import logging_setup
from deafrica_conflux.db import get_engine_waterbodies
from deafrica_conflux.id_field import guess_id_field
from deafrica_conflux.io import (
    check_file_exists,
    check_if_s3_uri,
    table_exists,
    write_table_to_parquet,
)
from deafrica_conflux.plugins.utils import run_plugin, validate_plugin
from deafrica_conflux.stack import stack_waterbodies_parquet_to_db

# %%
# These are the default AWS configurations for the Analysis Sandbox.
# that are set in the environmnet variables. 
aws_default_config = {
    #'AWS_NO_SIGN_REQUEST': 'YES', 
    'AWS_SECRET_ACCESS_KEY': 'fake',
    'AWS_ACCESS_KEY_ID': 'fake',
}

# To access public bucket, need to remove the AWS credentials in 
# the environment variables or the following error will occur.
# PermissionError: The AWS Access Key Id you provided does not exist in our records.

for key in aws_default_config.keys():
    if key in os.environ:
        del os.environ[key]

# %%
dataset_ids_file = "data/dataset_ids.txt"
verbose = 1
plugin_name = "waterbodies_timeseries_v2"
# This is the directory containing the parquet files for water body polygons split by wofs_ls regions.
polygons_directory = "s3://deafrica-waterbodies-dev/0-2-0/test_directory/polygons_split_by_region/"
# Unique key id in polygons vector files.
use_id = "UID"
# Directory to write the timeseries parquet files.
output_directory = "s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files"
# Rerun scenes that have already been processed.
overwrite = True
# Write to the Waterbodies database.
db = False
# Include polygons that only partially intersect the scene.
partial = True
# Include data from over the scene boundary.
overedge = True
# Not matter DataFrame is empty or not, always as it as Parquet file.
dump_empty_dataframe = True

# %%
# "Support" pathlib Paths.
dataset_ids_file = str(dataset_ids_file)
polygons_directory = str(polygons_directory)
output_directory = str(output_directory)

# %%
# Set up logger.
logging_setup(verbose)
_log = logging.getLogger(__name__)

# %%
# Read the plugin as a Python module.
module = import_module(f"deafrica_conflux.plugins.{plugin_name}")
plugin_file = module.__file__
plugin = run_plugin(plugin_file)
_log.info(f"Using plugin {plugin_file}")
validate_plugin(plugin)
# Out:
# [2023-10-26 18:13:36,754] {1894110324.py:5} INFO - Using plugin /home/jovyan/dev/deafrica-conflux/deafrica_conflux/plugins/waterbodies_timeseries_v2.py

# %%
# %%time
# Check if the text file containing dataset ids file exists.
if not check_file_exists(dataset_ids_file):
    _log.error(f"Could not find text file {dataset_ids_file}!")
    raise FileNotFoundError(f"Could not find text file {dataset_ids_file}!")
    
# Read ID/s from the S3 URI or File URI.
if check_if_s3_uri(dataset_ids_file):
    fs = fsspec.filesystem("s3")
else:
    fs = fsspec.filesystem("file")
    
with fs.open(dataset_ids_file, "r") as file:
    dataset_ids = [line.strip() for line in file]
_log.info(f"Read {dataset_ids} from file.")
# Out:
# [2023-10-26 18:13:36,761] {<timed exec>:14} INFO - Read ['936f161e-e5f3-5627-b8c7-834bfb5e8bcc', '56633394-d128-5b82-b366-f2ac6c7d391e', 'aaa1f697-ce35-557b-b406-86c6ab3120b7', 'c367b59e-faaf-5408-9214-89d5b6384032', 'f0b94027-593f-5e5c-8629-1fc13a6bcfdb', '75f93f21-a0e5-5d13-8683-822ed4fe6cbc'] from file.
# CPU times: user 1.87 ms, sys: 0 ns, total: 1.87 ms
# Wall time: 1.62 ms

# %%
if db:
    engine = get_engine_waterbodies()

# %%
# Connect to the datacube.
dc = datacube.Datacube(app="deafrica-conflux-drill")

# %%
# Get the product name from the plugin.
product_name = plugin.product_name

# %%
# As part of the drill function
import collections
import datetime
import logging
import multiprocessing
import warnings
import functools
from types import ModuleType

import datacube
import geopandas as gpd
import numpy as np
import pandas as pd
import shapely.geometry
import tqdm
import xarray as xr
from datacube.model import Dataset
from datacube.utils.geometry import Geometry
from deafrica_tools.spatial import xr_rasterize

from skimage.measure import regionprops
from deafrica_conflux.drill import get_intersections

# %%
def get_polygons_within_ds_extent(polygons_gdf: gpd.GeoDataFrame, ds: Dataset) -> gpd.GeoDataFrame:
    """
    Filter a set of polygons to include only polygons within (contained in) the extent of a dataset.
    """
    # Get the extent of the dataset.
    ds_extent = ds.extent
    ds_extent_crs = ds_extent.crs
    ds_extent_geom = ds_extent.geom
    ds_extent_gdf = gpd.GeoDataFrame(geometry=[ds_extent_geom], crs=ds_extent_crs).to_crs(polygons_gdf.crs)
    
    # Get all polygons that are contained withn the extent of the dataset.
    polygon_ids_within_ds_extent = ds_extent_gdf.sjoin(polygons_gdf, how="inner", predicate="contains")["index_right"].to_list()
    polygons_within_ds_extent = polygons_gdf.loc[polygon_ids_within_ds_extent]
    
    return polygons_within_ds_extent

# %%
def get_polygons_intersecting_ds_extent(polygons_gdf: gpd.GeoDataFrame, ds: Dataset) -> gpd.GeoDataFrame:
    """
    Filter a set of polygons to only include polygons that intersect with
    the extent of a dataset.

    Parameters
    ---------
    polygons_gdf : gpd.GeoDataFrame
    ds : Dataset

    Returns
    -------
    gpd.GeoDataFrame
    """
    # Get the extent of the dataset.
    ds_extent = ds.extent
    ds_extent_crs = ds_extent.crs
    ds_extent_geom = ds_extent.geom
    ds_extent_gdf = gpd.GeoDataFrame(geometry=[ds_extent_geom], crs=ds_extent_crs).to_crs(polygons_gdf.crs)

    # Get all polygons that intersect with the extent of the dataset.
    polygon_ids_intersecting_ds_extent = ds_extent_gdf.sjoin(polygons_gdf, how="inner", predicate="intersects")["index_right"].to_list()
    polygons_intersecting_ds_extent = polygons_gdf.loc[polygon_ids_intersecting_ds_extent]

    return polygons_intersecting_ds_extent

# %%
def filter_large_polygons(
    polygons_gdf: gpd.GeoDataFrame, ds: Dataset
) -> gpd.GeoDataFrame:
    """
    Filter out large polygons from the set of polygons.
    Large polygons are defined as polygons which are large than 3 scenes
    in width and in height.
    
    Arguments
    ---------
    polygons_gdf : gpd.GeoDataFrame
    ds : datacube.model.Dataset

    Returns
    -------
    gpd.GeoDataFrame
    """
    # Get the extent of the dataset.
    ds_extent = ds.extent

    # Reproject the extent of the dataset to match the set of polygons.
    ds_extent = ds_extent.to_crs(polygons_gdf.crs)

    # Get the bounding box of the extent of the dataset.
    bbox = ds_extent.boundingbox
    left, bottom, right, top = bbox

    # Create a polygon 3 dataset extents in width and height.
    width = right - left
    height = top - bottom

    testbox = shapely.geometry.Polygon(
        [
            (left - width, bottom - height),
            (left - width, top + height),
            (right + width, top + height),
            (right + width, bottom - height),
        ]
    )

    filtered_polygons_gdf = polygons_gdf[~polygons_gdf.geometry.intersects(testbox.boundary)]

    return filtered_polygons_gdf

# %%
def drill(
    plugin: ModuleType,
    polygons_gdf: gpd.GeoDataFrame,
    reference_dataset: Dataset,
    partial=True,
    overedge=True,
    dc: datacube.Datacube | None = None,
    time_buffer=datetime.timedelta(hours=1),
) -> pd.DataFrame:
    """
    Perform a polygon drill.

    Arguments
    ---------
    plugin : module
        A validated plugin to drill with.

    polygons_gdf : GeoDataFrame
        A GeoDataFrame with the ID (column containing the polygons ids) as the index.

    reference_dataset : Dataset
        Refernce dataset to process.

    partial : bool
        Optional (defaults to True). Whether to include polygons that partially
        overlap with the scene. If partial is True, polygons that partially
        overlap with the scene are included. If partial is False, polygons that
        partially overlap with the scene are excluded from the drill, and going
        off the edge of the scene will exclude the entire polygon. Describes
        what happens to the polygon, not what happens to the data. Interacts
        with overedge, which describes what happens to the overedge data.

    overedge : bool
        Optional (defaults to False). Whether to include data from other scenes
        in partially overedge polygons. If overedge is False, data from other
        scenes is not included in results. If overedge is True, data from other
        scenes is included in results. Interacts with partial.

    dc : datacube.Datacube
        Optional existing Datacube.

    time_buffer : datetime.timedelta
        Optional (default 1 hour). Only consider datasets within
        this time range for overedge.

    Returns
    -------
    Drill table : pd.DataFrame
        Index = polygon ID
        Columns = output bands
    """
    
    # Validate partial and overedge parameters.
    if not partial:
        if overedge:
            _log.error("overedge=True expects partial=True")
            raise ValueError("overedge=True expects partial=True")

    # TODO: Generalize to work with multiple products and 
    # products with multiple measurements measurements.

    # Check the plugin does not have multiple products to load.
    # Using multiple products is not is not implemented.
    if len(plugin.input_products.items()) > 1:
        raise NotImplementedError("Expected one product in plugin")
    else:
        reference_product = reference_dataset.type.name
        assert reference_product == list(plugin.input_products.keys())[0]
        measurements = plugin.input_products[reference_product]
        if len(measurements) > 1:
            raise NotImplementedError("Expected 1 measurement in plugin")
        else:
            measurement = measurements[0]

    # Get a datacube if we don't have one already.
    if dc is None:
        dc = datacube.Datacube(app="deafrica-conflux-drill")

    # Get the output crs and resolution from the plugin.
    output_crs = plugin.output_crs
    resolution = plugin.resolution
    if hasattr(plugin, "resampling"):
        resampling = plugin.resampling
    else:
        resampling = "nearest"

    # Reproject the polygons to the required CRS.
    polygons_gdf = polygons_gdf.to_crs(output_crs)

    # Filter the polygons based on the partial and overedge parameter.
    if partial:
        # Include polygons that partially overlap with the scene.
        # i.e. only  include polygons that intersect with the dataset extent.
        filtered_polygons_gdf = get_polygons_intersecting_ds_extent(polygons_gdf, reference_dataset)
        _log.info(f"Filtered out {len(polygons_gdf) - len(filtered_polygons_gdf)} polygons out of {len(polygons_gdf)} polygons.")
        if overedge:
            # If overedge, remove anything which intersects with a 3-scene
            # width box.
            n = len(filtered_polygons_gdf)
            filtered_polygons_gdf = filter_large_polygons(filtered_polygons_gdf, reference_dataset)
            _log.info(f"Overedge filter removed {n - len(filtered_polygons_gdf)} polygons larger than 3 scenes in width and height out of {n} polygons.")
    else:
        # Do not include polygons that partially overlap with the scene.
        # i.e. only include polygons within the dataset extent.
        filtered_polygons_gdf = get_polygons_within_ds_extent(polygons_gdf, reference_dataset)
        _log.info(f"Filtered out {len(polygons_gdf)- len(filtered_polygons_gdf)} polygons out of {len(polygons_gdf)} polygons.")

    if len(filtered_polygons_gdf) == 0:
        scene_uuid = str(reference_dataset.id)
        _log.warning(f"No polygons found in scene {scene_uuid}")
        return pd.DataFrame({})

    # Load the reference dataset.
    if overedge:
        # Search for all the datasets neighbouring our reference dataset that we need to cover 
        # the area of the polygons.

        # Get the bounding box for the polygons.
        geopolygon = Geometry(geom=shapely.geometry.box(*filtered_polygons_gdf.total_bounds), crs=filtered_polygons_gdf.crs)

        # TODO: Test using a 1 day
        # Get the time range to use for searching for datasets neighbouring our reference dataset.
        time_span = (reference_dataset.center_time - time_buffer, reference_dataset.center_time + time_buffer)

        req_datasets = dc.find_datasets(product=reference_product, geopolygon=geopolygon, time=time_span, ensure_location=True)

        reference_scene = dc.load(datasets=req_datasets,
                                  measurements=measurements,
                                  geopolygon=geopolygon,
                                  time=time_span,
                                  output_crs=output_crs,
                                  resolution=resolution,
                                  group_by="solar_day",
                                  resampling=resampling
                                 )

        _log.info(f"Loaded the {len(req_datasets)} required datasets to cover all the polygons: {', '.join([str(dataset.id) for dataset in req_datasets])} .")

    else:    
        # Load the reference scene.
        reference_scene = dc.load(datasets=[reference_dataset], measurements=measurements, output_crs=output_crs, resolution=resolution, resampling=resampling)

        _log.info(f"Loaded the reference dataset {str(reference_dataset.id)} ." )


    _log.info(f"Reference scene is {reference_scene.sizes}")

    # Transform the loaded data.
    # Force warnings to raise exceptions.
    # This means users have to explicitly ignore warnings.
    ds = reference_scene.isel(time=0)
    with warnings.catch_warnings():
        warnings.filterwarnings("error")
        ds_transformed = plugin.transform(ds)[measurement]


    # Assign a one-indexed numeric column for the polygons.
    # This will allow us to build a polygon enumerated raster.
    attr_col = "_conflux_one_index"
    # This mutates the (in-memory) polygons_gdf, but that's OK.
    filtered_polygons_gdf[attr_col] = range(1, len(filtered_polygons_gdf.index) + 1)
    conflux_one_index_to_id = {v: k for k, v in filtered_polygons_gdf[attr_col].to_dict().items()}

    # Build the enumerated polygon raster.
    polygon_raster = xr_rasterize(filtered_polygons_gdf, reference_scene, attr_col)

    # Get the summaries.
    # Convert the xarrat.DataArrays to a numpy array for image processing.
    np_polygon_raster = polygon_raster.to_numpy().astype(int)

    np_ds_transformed = ds_transformed.to_numpy().astype(float)

    # For each polygon, perform the summary.
    props = regionprops(
            label_image=np_polygon_raster, intensity_image=np_ds_transformed, extra_properties=(plugin.summarise,)
        )
    summary_df_list = []
    for region_prop in props:
        polygon_summary_df = region_prop.summarise
        polygon_index = conflux_one_index_to_id[region_prop.label]
        polygon_summary_df.index = [polygon_index]
        summary_df_list.append(polygon_summary_df)

    summary_df = pd.concat(summary_df_list, ignore_index=False)

    # Detect intersections.
    # We only have to do this if partial and not overedge.
    # If not partial, then there can't be any intersections.
    # If overedge, then there are no partly observed polygons.
    if partial and not overedge:
        intersection_features = get_intersections(filtered_polygons_gdf, reference_scene.extent)
        intersection_features.rename(
            inplace=True,
            columns={
                "North": "conflux_n",
                "South": "conflux_s",
                "East": "conflux_e",
                "West": "conflux_w",
            },
        )
        # Merge in the edge information.
        summary_df = summary_df.join(
            # left join only includes objects with some
            # representation in the scene
            intersection_features,
            how="left",
        )

    return summary_df

# %%
# %%time
failed_dataset_ids = []
for i, dataset_id in enumerate(dataset_ids):
    _log.info(f"Processing {dataset_id} ({i + 1}/{len(dataset_ids)})")
    
    # Load the dataset using the dataset id.
    reference_dataset = dc.index.datasets.get(dataset_id)
    
    # Get the region code for the dataset.
    region_code = reference_dataset.metadata.region_code
    
    # Get the center time for the dataset
    centre_time = reference_dataset.center_time
  
    # Use the center time to check if a parquet file for the dataset already
    # exists in the output directory.
    if not overwrite:
        _log.info(f"Checking existence of {dataset_id}")
        exists = table_exists(product_name, dataset_id, centre_time, output_directory)
    
    if overwrite or not exists:
        try:
            # Load the water body polygons for the region
            polygons_vector_file = os.path.join(polygons_directory, f"{region_code}.parquet")
            try:
                polygons_gdf = gpd.read_parquet(polygons_vector_file)
            except Exception as error:
                _log.exception(f"Could not read file {polygons_vector_file}")
                raise error
            else:
                # Guess the ID field.
                id_field = guess_id_field(polygons_gdf, use_id)
                _log.debug(f"Guessed ID field: {id_field}")

                # Set the ID field as the index.
                polygons_gdf.set_index(id_field, inplace=True)
                
            # Perform the polygon drill on the dataset
            table = drill(plugin,
                          polygons_gdf,
                          reference_dataset,
                          partial,
                          overedge, 
                          dc)
            # Write the table to a parquet file.
            if (dump_empty_dataframe) or (not table.empty):
                pq_filename = write_table_to_parquet(product_name, dataset_id, centre_time, table, output_directory)
                if db:
                    log.info(f"Writing {pq_filename} to database")
                    stack_waterbodies_parquet_to_db(parquet_file_paths=[pq_filename], verbose=verbose, engine=engine, drop=False,)
        except KeyError as keyerr:
            log.exception(f"Found {dataset_id} has KeyError: {str(keyerr)}")
            failed_dataset_ids.append(dataset_id)
        except TypeError as typeerr:
            _log.exception(f"Found {dataset_id} has TypeError: {str(typeerr)}")
            failed_dataset_ids.append(dataset_id)
        except RasterioIOError as ioerror:
            _log.exception(f"Found {dataset_id} has RasterioIOError: {str(ioerror)}")
            failed_dataset_ids.append(dataset_id)
        else:
            _log.info(f"{dataset_id} successful")
    else:
        _log.info(f"{dataset_id} already exists, skipping")

    if failed_dataset_ids:
        # Write the failed dataset ids to a text file.
        parent_folder, file_name = os.path.split(dataset_ids_file)
        file, file_extension = os.path.splitext(file_name)
        failed_datasets_text_file = os.path.join(
            parent_folder, file + "_failed_dataset_ids" + file_extension
        )

        with fs.open(failed_datasets_text_file, "a") as file:
            for dataset_id in failed_dataset_ids:
                file.write(f"{dataset_id}\n")

        _log.info(f"Failed dataset IDs {failed_dataset_ids} written to: {failed_datasets_text_file}.")
# Out:
# [2023-10-26 18:13:37,473] {<timed exec>:3} INFO - Processing 936f161e-e5f3-5627-b8c7-834bfb5e8bcc (1/6)
# [2023-10-26 18:13:37,791] {id_field.py:64} INFO - Values in the column UID are unique.
# [2023-10-26 18:13:38,002] {340435804.py:95} INFO - Filtered out 1463 polygons out of 1737 polygons.
# [2023-10-26 18:13:41,302] {340435804.py:101} INFO - Overedge filter removed 1 polygons larger than 3 scenes in width and height out of 274 polygons.
# [2023-10-26 18:13:44,020] {340435804.py:137} INFO - Loaded the 3 required datasets to cover all the polygons: 936f161e-e5f3-5627-b8c7-834bfb5e8bcc, 56633394-d128-5b82-b366-f2ac6c7d391e, 5f9dc6b0-bd63-5382-915f-6e1074bb6975 .
# [2023-10-26 18:13:44,021] {340435804.py:146} INFO - Reference scene is Frozen({'time': 1, 'y': 6553, 'x': 5972})
# [2023-10-26 18:13:45,277] {credentials.py:620} INFO - Found credentials in shared credentials file: ~/.aws/credentials
# [2023-10-26 18:13:45,635] {io.py:258} INFO - Table written to s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files/20030108/waterbodies_936f161e-e5f3-5627-b8c7-834bfb5e8bcc_20030108-075549-325285.pq
# [2023-10-26 18:13:45,636] {<timed exec>:60} INFO - 936f161e-e5f3-5627-b8c7-834bfb5e8bcc successful
# [2023-10-26 18:13:45,637] {<timed exec>:3} INFO - Processing 56633394-d128-5b82-b366-f2ac6c7d391e (2/6)
# [2023-10-26 18:13:45,873] {id_field.py:64} INFO - Values in the column UID are unique.
# [2023-10-26 18:13:46,030] {340435804.py:95} INFO - Filtered out 1174 polygons out of 2460 polygons.
# [2023-10-26 18:13:49,288] {340435804.py:101} INFO - Overedge filter removed 1 polygons larger than 3 scenes in width and height out of 1286 polygons.
# [2023-10-26 18:13:52,219] {340435804.py:137} INFO - Loaded the 3 required datasets to cover all the polygons: 936f161e-e5f3-5627-b8c7-834bfb5e8bcc, 56633394-d128-5b82-b366-f2ac6c7d391e, 450fcbc5-2151-557e-87bf-a1c0ef66899c .
# [2023-10-26 18:13:52,220] {340435804.py:146} INFO - Reference scene is Frozen({'time': 1, 'y': 8010, 'x': 5882})
# [2023-10-26 18:13:54,819] {io.py:258} INFO - Table written to s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files/20030108/waterbodies_56633394-d128-5b82-b366-f2ac6c7d391e_20030108-075613-246022.pq
# [2023-10-26 18:13:54,821] {<timed exec>:60} INFO - 56633394-d128-5b82-b366-f2ac6c7d391e successful
# [2023-10-26 18:13:54,821] {<timed exec>:3} INFO - Processing aaa1f697-ce35-557b-b406-86c6ab3120b7 (3/6)
# [2023-10-26 18:13:55,080] {id_field.py:64} INFO - Values in the column UID are unique.
# [2023-10-26 18:13:55,215] {340435804.py:95} INFO - Filtered out 541 polygons out of 1315 polygons.
# [2023-10-26 18:13:58,442] {340435804.py:101} INFO - Overedge filter removed 1 polygons larger than 3 scenes in width and height out of 774 polygons.
# [2023-10-26 18:14:01,469] {340435804.py:137} INFO - Loaded the 3 required datasets to cover all the polygons: aaa1f697-ce35-557b-b406-86c6ab3120b7, c367b59e-faaf-5408-9214-89d5b6384032, 180e9b24-c477-5c5e-82fe-d863f0271fa2 .
# [2023-10-26 18:14:01,470] {340435804.py:146} INFO - Reference scene is Frozen({'time': 1, 'y': 7596, 'x': 6159})
# [2023-10-26 18:14:03,281] {io.py:258} INFO - Table written to s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files/20030110/waterbodies_aaa1f697-ce35-557b-b406-86c6ab3120b7_20030110-074418-013025.pq
# [2023-10-26 18:14:03,282] {<timed exec>:60} INFO - aaa1f697-ce35-557b-b406-86c6ab3120b7 successful
# [2023-10-26 18:14:03,284] {<timed exec>:3} INFO - Processing c367b59e-faaf-5408-9214-89d5b6384032 (4/6)
# [2023-10-26 18:14:03,535] {id_field.py:64} INFO - Values in the column UID are unique.
# [2023-10-26 18:14:03,663] {340435804.py:95} INFO - Filtered out 260 polygons out of 993 polygons.
# [2023-10-26 18:14:06,926] {340435804.py:101} INFO - Overedge filter removed 0 polygons larger than 3 scenes in width and height out of 733 polygons.
# [2023-10-26 18:14:11,312] {340435804.py:137} INFO - Loaded the 3 required datasets to cover all the polygons: aaa1f697-ce35-557b-b406-86c6ab3120b7, c367b59e-faaf-5408-9214-89d5b6384032, f0b94027-593f-5e5c-8629-1fc13a6bcfdb .
# [2023-10-26 18:14:11,313] {340435804.py:146} INFO - Reference scene is Frozen({'time': 1, 'y': 15099, 'x': 10788})
# [2023-10-26 18:14:52,095] {io.py:258} INFO - Table written to s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files/20030110/waterbodies_c367b59e-faaf-5408-9214-89d5b6384032_20030110-074354-077131.pq
# [2023-10-26 18:14:52,097] {<timed exec>:60} INFO - c367b59e-faaf-5408-9214-89d5b6384032 successful
# [2023-10-26 18:14:52,098] {<timed exec>:3} INFO - Processing f0b94027-593f-5e5c-8629-1fc13a6bcfdb (5/6)
# [2023-10-26 18:14:52,441] {id_field.py:64} INFO - Values in the column UID are unique.
# [2023-10-26 18:14:52,590] {340435804.py:95} INFO - Filtered out 777 polygons out of 2077 polygons.
# [2023-10-26 18:14:55,764] {340435804.py:101} INFO - Overedge filter removed 1 polygons larger than 3 scenes in width and height out of 1300 polygons.
# [2023-10-26 18:14:58,741] {340435804.py:137} INFO - Loaded the 3 required datasets to cover all the polygons: c367b59e-faaf-5408-9214-89d5b6384032, f0b94027-593f-5e5c-8629-1fc13a6bcfdb, 930727f8-ed81-5275-aa76-b1b9624e7d1c .
# [2023-10-26 18:14:58,741] {340435804.py:146} INFO - Reference scene is Frozen({'time': 1, 'y': 7839, 'x': 5660})
# [2023-10-26 18:15:01,054] {io.py:258} INFO - Table written to s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files/20030110/waterbodies_f0b94027-593f-5e5c-8629-1fc13a6bcfdb_20030110-074330-160970.pq
# [2023-10-26 18:15:01,055] {<timed exec>:60} INFO - f0b94027-593f-5e5c-8629-1fc13a6bcfdb successful
# [2023-10-26 18:15:01,056] {<timed exec>:3} INFO - Processing 75f93f21-a0e5-5d13-8683-822ed4fe6cbc (6/6)
# [2023-10-26 18:15:01,362] {id_field.py:64} INFO - Values in the column UID are unique.
# [2023-10-26 18:15:01,515] {340435804.py:95} INFO - Filtered out 747 polygons out of 1736 polygons.
# [2023-10-26 18:15:04,775] {340435804.py:101} INFO - Overedge filter removed 1 polygons larger than 3 scenes in width and height out of 989 polygons.
# [2023-10-26 18:15:08,535] {340435804.py:137} INFO - Loaded the 3 required datasets to cover all the polygons: 75f93f21-a0e5-5d13-8683-822ed4fe6cbc, e78f07ea-6247-5d2c-85a4-3e636ebe3435, ff038cde-583f-588a-b063-21cb59e45b76 .
# [2023-10-26 18:15:08,536] {340435804.py:146} INFO - Reference scene is Frozen({'time': 1, 'y': 12779, 'x': 6313})
# [2023-10-26 18:15:12,205] {io.py:258} INFO - Table written to s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files/20030117/waterbodies_75f93f21-a0e5-5d13-8683-822ed4fe6cbc_20030117-074946-854120.pq
# [2023-10-26 18:15:12,206] {<timed exec>:60} INFO - 75f93f21-a0e5-5d13-8683-822ed4fe6cbc successful
# CPU times: user 1min 28s, sys: 5.84 s, total: 1min 34s
# Wall time: 1min 34s

# %%
from deafrica_conflux.stack import StackMode, stack_parquet

# Stack the waterbodies files
"""
Stack outputs of deafrica-conflux into other formats.
"""
# Path to the Parquet directory
parquet_path = "s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files"
pattern = ".*"
# Output directory for waterbodies-style stack
stack_output_directory = 's3://deafrica-waterbodies-dev/0-2-0/test_directory'
mode = "waterbodies"
# Remove timeseries duplicated data if applicable. 
remove_duplicated_data = True
# Convert mode to StackMode
mode_map = {
    "waterbodies": StackMode.WATERBODIES,
    "waterbodies_db": StackMode.WATERBODIES_DB,
}


kwargs = {}
if mode == "waterbodies":
    kwargs["output_directory"] = stack_output_directory
    kwargs["remove_duplicated_data"] = remove_duplicated_data
elif mode == "waterbodies_db":
    kwargs["drop"] = drop

stack_parquet(
    path=parquet_path, pattern=pattern, mode=mode_map[mode], verbose=verbose, **kwargs
)
# Out:
# [2023-10-26 18:17:27,015] {stack.py:543} INFO - Begin to query s3://deafrica-waterbodies-dev/0-2-0/test_directory/pq_files with pattern .*
# [2023-10-26 18:17:27,382] {stack.py:113} INFO - Found 6 parquet files.
# [2023-10-26 18:17:27,383] {stack.py:252} INFO - Reading...
#   0%|          | 0/6 [00:00<?, ?it/s]
# [2023-10-26 18:17:28,042] {stack.py:265} INFO - Writing...
# [2023-10-26 18:17:28,046] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte6fxgx.csv
# [2023-10-26 18:17:28,075] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte3zzgp.csv
# [2023-10-26 18:17:28,101] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte82w1t.csv
# [2023-10-26 18:17:28,126] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte810ze.csv
# [2023-10-26 18:17:28,155] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte83xg3.csv
# [2023-10-26 18:17:28,180] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8d42k.csv
# [2023-10-26 18:17:28,204] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8dhkr.csv
# [2023-10-26 18:17:28,227] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8dq2y.csv
# [2023-10-26 18:17:28,254] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte860my.csv
# [2023-10-26 18:17:28,279] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte867gk.csv
# [2023-10-26 18:17:28,305] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8e18v.csv
# [2023-10-26 18:17:28,332] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8ejz7.csv
# [2023-10-26 18:17:28,354] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8e37c.csv
# [2023-10-26 18:17:28,380] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8e8g2.csv
# [2023-10-26 18:17:28,407] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8g9su.csv
# [2023-10-26 18:17:28,437] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte87w69.csv
# [2023-10-26 18:17:28,461] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte9khb0.csv
# [2023-10-26 18:17:28,491] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8k7m6.csv
# [2023-10-26 18:17:28,521] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7xsd5e.csv
# [2023-10-26 18:17:28,544] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7xt4kd.csv
# [2023-10-26 18:17:28,566] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7xvq67.csv
# [2023-10-26 18:17:28,595] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8mct8.csv
# [2023-10-26 18:17:28,619] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8nv9q.csv
# [2023-10-26 18:17:28,643] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8xnsv.csv
# [2023-10-26 18:17:28,666] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxte8xkhg.csv
# [2023-10-26 18:17:28,693] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtebb6f7.csv
# [2023-10-26 18:17:28,718] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtebbu5y.csv
# [2023-10-26 18:17:28,746] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxteb1577.csv
# [2023-10-26 18:17:28,778] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtebc3r6.csv
# [2023-10-26 18:17:28,805] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtemhg70.csv
# [2023-10-26 18:17:28,834] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxteft5hm.csv
# [2023-10-26 18:17:28,861] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxteyw8tv.csv
# [2023-10-26 18:17:28,889] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsn6yey.csv
# [2023-10-26 18:17:28,911] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsm3rwz.csv
# [2023-10-26 18:17:28,935] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxteb9xdd.csv
# [2023-10-26 18:17:28,962] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtebej0m.csv
# [2023-10-26 18:17:28,991] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtebdep0.csv
# [2023-10-26 18:17:29,011] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxteb7h5z.csv
# [2023-10-26 18:17:29,034] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtebssps.csv
# [2023-10-26 18:17:29,061] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtebv7un.csv
# [2023-10-26 18:17:29,082] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxte/kxtebwmp6.csv
# [2023-10-26 18:17:29,117] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxts08urz.csv
# [2023-10-26 18:17:29,167] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxts0d5zg.csv
# [2023-10-26 18:17:29,192] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxts0k6t7.csv
# [2023-10-26 18:17:29,215] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7vh6g6.csv
# [2023-10-26 18:17:29,240] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7ypd42.csv
# [2023-10-26 18:17:29,265] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk505b5.csv
# [2023-10-26 18:17:29,293] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkn00cy.csv
# [2023-10-26 18:17:29,320] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk5069u.csv
# [2023-10-26 18:17:29,349] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkjfh2d.csv
# [2023-10-26 18:17:29,373] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkhhdr3.csv
# [2023-10-26 18:17:29,398] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk5v1hx.csv
# [2023-10-26 18:17:29,424] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk4vfqx.csv
# [2023-10-26 18:17:29,448] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk4ypvq.csv
# [2023-10-26 18:17:29,474] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtg/kxtg2kesp.csv
# [2023-10-26 18:17:29,497] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtu318nb.csv
# [2023-10-26 18:17:29,520] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsrcfmh.csv
# [2023-10-26 18:17:29,545] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtuc9jck.csv
# [2023-10-26 18:17:29,572] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtub4d4r.csv
# [2023-10-26 18:17:29,604] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtub777y.csv
# [2023-10-26 18:17:29,633] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtv33mdq.csv
# [2023-10-26 18:17:29,656] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtv3mqv3.csv
# [2023-10-26 18:17:29,682] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtv3z8kt.csv
# [2023-10-26 18:17:29,709] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtknrtsg.csv
# [2023-10-26 18:17:29,732] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkhzep7.csv
# [2023-10-26 18:17:29,755] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk5zep5.csv
# [2023-10-26 18:17:29,784] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtknrc7x.csv
# [2023-10-26 18:17:29,814] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkm21bd.csv
# [2023-10-26 18:17:29,840] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkk2prx.csv
# [2023-10-26 18:17:29,863] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkm22bs.csv
# [2023-10-26 18:17:29,886] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkm2kbr.csv
# [2023-10-26 18:17:29,913] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkq0w8y.csv
# [2023-10-26 18:17:29,941] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkkb8bz.csv
# [2023-10-26 18:17:29,964] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkr09fm.csv
# [2023-10-26 18:17:29,995] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkkdj2x.csv
# [2023-10-26 18:17:30,018] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkq6wwy.csv
# [2023-10-26 18:17:30,045] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkmep0y.csv
# [2023-10-26 18:17:30,071] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk675yn.csv
# [2023-10-26 18:17:30,098] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkqeq7u.csv
# [2023-10-26 18:17:30,123] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkmgd89.csv
# [2023-10-26 18:17:30,148] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkmgsec.csv
# [2023-10-26 18:17:30,171] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk6hp8z.csv
# [2023-10-26 18:17:30,200] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk6kkvz.csv
# [2023-10-26 18:17:30,227] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7txz2m.csv
# [2023-10-26 18:17:30,256] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7f246c.csv
# [2023-10-26 18:17:30,288] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7f3wdh.csv
# [2023-10-26 18:17:30,312] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7fdm0v.csv
# [2023-10-26 18:17:30,336] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7fdwcr.csv
# [2023-10-26 18:17:30,360] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7ff8jt.csv
# [2023-10-26 18:17:30,384] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7gfz8h.csv
# [2023-10-26 18:17:30,408] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxt7/kxt7f7zev.csv
# [2023-10-26 18:17:30,432] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkhqmn4.csv
# [2023-10-26 18:17:30,457] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk5nwvn.csv
# [2023-10-26 18:17:30,485] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk5nfbt.csv
# [2023-10-26 18:17:30,509] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk5rjc5.csv
# [2023-10-26 18:17:30,537] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkhqvju.csv
# [2023-10-26 18:17:30,561] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkhrr4e.csv
# [2023-10-26 18:17:30,584] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkjpt47.csv
# [2023-10-26 18:17:30,609] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkhx7j8.csv
# [2023-10-26 18:17:30,639] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk5psv1.csv
# [2023-10-26 18:17:30,667] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkhzd8u.csv
# [2023-10-26 18:17:30,690] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkk2sbc.csv
# [2023-10-26 18:17:30,715] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkkbc9d.csv
# [2023-10-26 18:17:30,739] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk62vsq.csv
# [2023-10-26 18:17:30,764] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkk8gsg.csv
# [2023-10-26 18:17:30,789] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkk2yj5.csv
# [2023-10-26 18:17:30,815] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkm90k4.csv
# [2023-10-26 18:17:30,838] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkk95q3.csv
# [2023-10-26 18:17:30,866] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkk3m5u.csv
# [2023-10-26 18:17:30,892] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk7ctef.csv
# [2023-10-26 18:17:30,918] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkm9dsh.csv
# [2023-10-26 18:17:30,948] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkdcjc0.csv
# [2023-10-26 18:17:30,975] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtke14kr.csv
# [2023-10-26 18:17:31,005] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtke4d43.csv
# [2023-10-26 18:17:31,031] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkdg206.csv
# [2023-10-26 18:17:31,061] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkds2gh.csv
# [2023-10-26 18:17:31,084] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkwv7q2.csv
# [2023-10-26 18:17:31,117] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkdtcwc.csv
# [2023-10-26 18:17:31,146] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkwy533.csv
# [2023-10-26 18:17:31,170] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkdw7jq.csv
# [2023-10-26 18:17:31,200] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtf/kxtfv8tsh.csv
# [2023-10-26 18:17:31,230] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtg/kxtgj3sm6.csv
# [2023-10-26 18:17:31,258] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtg/kxtgj7ph2.csv
# [2023-10-26 18:17:31,280] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtg/kxtgj7weq.csv
# [2023-10-26 18:17:31,309] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtg/kxtgjn7zq.csv
# [2023-10-26 18:17:31,335] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtg/kxtgm6x3d.csv
# [2023-10-26 18:17:31,367] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtum574n.csv
# [2023-10-26 18:17:31,397] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtut4zev.csv
# [2023-10-26 18:17:31,421] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtu7gm9t.csv
# [2023-10-26 18:17:31,447] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtucyng6.csv
# [2023-10-26 18:17:31,473] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtuskv4s.csv
# [2023-10-26 18:17:31,507] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtutrg3k.csv
# [2023-10-26 18:17:31,561] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtu/kxtuu7xjm.csv
# [2023-10-26 18:17:31,599] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvj59rv.csv
# [2023-10-26 18:17:31,625] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvjj5tr.csv
# [2023-10-26 18:17:31,666] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvjnjvw.csv
# [2023-10-26 18:17:31,696] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvjnxev.csv
# [2023-10-26 18:17:31,730] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvjr2bj.csv
# [2023-10-26 18:17:31,764] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvk6bvw.csv
# [2023-10-26 18:17:31,794] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvjrb5g.csv
# [2023-10-26 18:17:31,822] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvm28ep.csv
# [2023-10-26 18:17:31,844] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvm3cy3.csv
# [2023-10-26 18:17:31,905] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvm67wg.csv
# [2023-10-26 18:17:31,935] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvm7jyc.csv
# [2023-10-26 18:17:31,958] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvt2mts.csv
# [2023-10-26 18:17:31,983] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvt2e55.csv
# [2023-10-26 18:17:32,008] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvt33th.csv
# [2023-10-26 18:17:32,039] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvt6h1m.csv
# [2023-10-26 18:17:32,070] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvt6q4t.csv
# [2023-10-26 18:17:32,096] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvv19rs.csv
# [2023-10-26 18:17:32,121] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtv7sgej.csv
# [2023-10-26 18:17:32,151] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtv6q67w.csv
# [2023-10-26 18:17:32,176] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvewnzf.csv
# [2023-10-26 18:17:32,203] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvu1fzs.csv
# [2023-10-26 18:17:32,234] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvujj0s.csv
# [2023-10-26 18:17:32,263] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty5zvzn.csv
# [2023-10-26 18:17:32,291] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty7v9e5.csv
# [2023-10-26 18:17:32,312] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtykjcj1.csv
# [2023-10-26 18:17:32,334] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtykn8u0.csv
# [2023-10-26 18:17:32,357] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyknthy.csv
# [2023-10-26 18:17:32,380] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvu9vmf.csv
# [2023-10-26 18:17:32,409] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvv61bb.csv
# [2023-10-26 18:17:32,432] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvv4khh.csv
# [2023-10-26 18:17:32,461] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvuf7y4.csv
# [2023-10-26 18:17:32,484] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvufqmd.csv
# [2023-10-26 18:17:32,506] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvv6v9p.csv
# [2023-10-26 18:17:32,534] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvvkwjb.csv
# [2023-10-26 18:17:32,555] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvupp7x.csv
# [2023-10-26 18:17:32,578] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyh2vrw.csv
# [2023-10-26 18:17:32,603] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyh35s7.csv
# [2023-10-26 18:17:32,627] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtv9dgtq.csv
# [2023-10-26 18:17:32,658] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvcw9b0.csv
# [2023-10-26 18:17:32,684] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvcxdwt.csv
# [2023-10-26 18:17:32,707] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty18dxn.csv
# [2023-10-26 18:17:32,728] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty1s63c.csv
# [2023-10-26 18:17:32,751] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty228yf.csv
# [2023-10-26 18:17:32,774] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty3k0fs.csv
# [2023-10-26 18:17:32,798] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty2qn4h.csv
# [2023-10-26 18:17:32,821] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty2w2tz.csv
# [2023-10-26 18:17:32,844] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty2wb8p.csv
# [2023-10-26 18:17:32,870] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyh3skd.csv
# [2023-10-26 18:17:32,893] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyj4n4w.csv
# [2023-10-26 18:17:32,916] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyj6whq.csv
# [2023-10-26 18:17:32,938] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyheskn.csv
# [2023-10-26 18:17:32,962] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyjk03x.csv
# [2023-10-26 18:17:32,985] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyjmfqb.csv
# [2023-10-26 18:17:33,005] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyjrp0k.csv
# [2023-10-26 18:17:33,027] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyhxymj.csv
# [2023-10-26 18:17:33,056] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyhrgzv.csv
# [2023-10-26 18:17:33,079] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtykb1b1.csv
# [2023-10-26 18:17:33,101] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtv/kxtvvy8s7.csv
# [2023-10-26 18:17:33,125] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyj84hp.csv
# [2023-10-26 18:17:33,146] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyjb0ds.csv
# [2023-10-26 18:17:33,168] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyj8cmu.csv
# [2023-10-26 18:17:33,192] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyj9b09.csv
# [2023-10-26 18:17:33,214] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtym8z89.csv
# [2023-10-26 18:17:33,237] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtym9nv8.csv
# [2023-10-26 18:17:33,259] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtym9pxy.csv
# [2023-10-26 18:17:33,282] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtymdndc.csv
# [2023-10-26 18:17:33,302] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtymx22f.csv
# [2023-10-26 18:17:33,329] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtym2hwr.csv
# [2023-10-26 18:17:33,353] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtykd95c.csv
# [2023-10-26 18:17:33,377] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtym6wr7.csv
# [2023-10-26 18:17:33,408] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtymk9sy.csv
# [2023-10-26 18:17:33,430] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtymmten.csv
# [2023-10-26 18:17:33,459] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtymqxqj.csv
# [2023-10-26 18:17:33,483] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtykr0n2.csv
# [2023-10-26 18:17:33,509] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtys205d.csv
# [2023-10-26 18:17:33,533] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtys27m1.csv
# [2023-10-26 18:17:33,558] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtys8d6f.csv
# [2023-10-26 18:17:33,583] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkdqwpn.csv
# [2023-10-26 18:17:33,611] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkdwvn0.csv
# [2023-10-26 18:17:33,634] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkdxq5s.csv
# [2023-10-26 18:17:33,661] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkf8nfy.csv
# [2023-10-26 18:17:33,685] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkf8ube.csv
# [2023-10-26 18:17:33,713] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkf9rkt.csv
# [2023-10-26 18:17:33,741] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkfdkyr.csv
# [2023-10-26 18:17:33,767] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkfsm2x.csv
# [2023-10-26 18:17:33,798] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkghfz9.csv
# [2023-10-26 18:17:33,822] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkfuuzf.csv
# [2023-10-26 18:17:33,844] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkftnw6.csv
# [2023-10-26 18:17:33,870] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkfwv2p.csv
# [2023-10-26 18:17:33,891] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkuz5ew.csv
# [2023-10-26 18:17:33,915] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkfwcpc.csv
# [2023-10-26 18:17:33,944] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkfx7fc.csv
# [2023-10-26 18:17:33,966] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkgzf8y.csv
# [2023-10-26 18:17:33,988] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtm43h23.csv
# [2023-10-26 18:17:34,017] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtm46cc4.csv
# [2023-10-26 18:17:34,044] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmhj8fm.csv
# [2023-10-26 18:17:34,067] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtm5vtwy.csv
# [2023-10-26 18:17:34,092] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmhn0rq.csv
# [2023-10-26 18:17:34,113] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmhn3p2.csv
# [2023-10-26 18:17:34,137] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmhngfw.csv
# [2023-10-26 18:17:34,162] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmhp568.csv
# [2023-10-26 18:17:34,186] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmk879j.csv
# [2023-10-26 18:17:34,210] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmk2e42.csv
# [2023-10-26 18:17:34,232] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmk2we8.csv
# [2023-10-26 18:17:34,260] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmk9u62.csv
# [2023-10-26 18:17:34,287] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkqu7q4.csv
# [2023-10-26 18:17:34,308] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk6kg9k.csv
# [2023-10-26 18:17:34,331] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkqv04s.csv
# [2023-10-26 18:17:34,353] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk6my4w.csv
# [2023-10-26 18:17:34,398] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk6tuqg.csv
# [2023-10-26 18:17:34,428] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk6wt3k.csv
# [2023-10-26 18:17:34,458] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk6y8k7.csv
# [2023-10-26 18:17:34,482] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk6z3gk.csv
# [2023-10-26 18:17:34,514] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtk7p3k0.csv
# [2023-10-26 18:17:34,536] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkdbtey.csv
# [2023-10-26 18:17:34,564] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtssdsg9.csv
# [2023-10-26 18:17:34,586] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsegsvt.csv
# [2023-10-26 18:17:34,610] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtseu1ss.csv
# [2023-10-26 18:17:34,635] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsdt13z.csv
# [2023-10-26 18:17:34,659] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsstxcw.csv
# [2023-10-26 18:17:34,681] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtssv9vx.csv
# [2023-10-26 18:17:34,706] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsu32m5.csv
# [2023-10-26 18:17:34,733] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsvepqb.csv
# [2023-10-26 18:17:34,755] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsgz0gp.csv
# [2023-10-26 18:17:34,782] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsfxqfy.csv
# [2023-10-26 18:17:34,811] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxts0hxq8.csv
# [2023-10-26 18:17:34,839] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxts9s61v.csv
# [2023-10-26 18:17:34,863] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsc1uzv.csv
# [2023-10-26 18:17:34,889] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtk/kxtkzungm.csv
# [2023-10-26 18:17:34,910] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsbh4ed.csv
# [2023-10-26 18:17:34,933] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxtt0vdyx.csv
# [2023-10-26 18:17:34,959] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxtt0ymwf.csv
# [2023-10-26 18:17:34,987] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxtt1p4gf.csv
# [2023-10-26 18:17:35,010] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxtt1p1kt.csv
# [2023-10-26 18:17:35,036] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtm/kxtmxdcc0.csv
# [2023-10-26 18:17:35,086] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxts/kxtsfxsgx.csv
# [2023-10-26 18:17:35,110] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxttp08cq.csv
# [2023-10-26 18:17:35,133] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxtt7qp48.csv
# [2023-10-26 18:17:35,163] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxtt7xtx2.csv
# [2023-10-26 18:17:35,191] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxtttfhkx.csv
# [2023-10-26 18:17:35,215] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxttv94y1.csv
# [2023-10-26 18:17:35,254] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxttfmxtt.csv
# [2023-10-26 18:17:35,279] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtt/kxttzq93v.csv
# [2023-10-26 18:17:35,302] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtw4cksc.csv
# [2023-10-26 18:17:35,333] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwnu33v.csv
# [2023-10-26 18:17:35,356] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwny630.csv
# [2023-10-26 18:17:35,378] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwhpcjj.csv
# [2023-10-26 18:17:35,401] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwk1f8e.csv
# [2023-10-26 18:17:35,424] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwmcbxp.csv
# [2023-10-26 18:17:35,448] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwrj89s.csv
# [2023-10-26 18:17:35,474] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwqz9kd.csv
# [2023-10-26 18:17:35,497] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwe1js7.csv
# [2023-10-26 18:17:35,530] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwwnpp7.csv
# [2023-10-26 18:17:35,555] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwv1hc2.csv
# [2023-10-26 18:17:35,579] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwz7tm2.csv
# [2023-10-26 18:17:35,604] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty828gz.csv
# [2023-10-26 18:17:35,627] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty85x10.csv
# [2023-10-26 18:17:35,651] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty8hjdz.csv
# [2023-10-26 18:17:35,674] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty8pf8t.csv
# [2023-10-26 18:17:35,702] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty8pcsb.csv
# [2023-10-26 18:17:35,726] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyb01ge.csv
# [2023-10-26 18:17:35,747] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyb03j8.csv
# [2023-10-26 18:17:35,772] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyb0dqj.csv
# [2023-10-26 18:17:35,795] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyb1u5x.csv
# [2023-10-26 18:17:35,819] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyb45nz.csv
# [2023-10-26 18:17:35,844] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwy5zj5.csv
# [2023-10-26 18:17:35,865] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwgkj9d.csv
# [2023-10-26 18:17:35,886] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwuk695.csv
# [2023-10-26 18:17:35,911] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwvhu1k.csv
# [2023-10-26 18:17:35,934] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwvt235.csv
# [2023-10-26 18:17:35,956] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwvptku.csv
# [2023-10-26 18:17:36,010] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxpd113.csv
# [2023-10-26 18:17:36,035] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtx45ruk.csv
# [2023-10-26 18:17:36,058] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtx4w1sx.csv
# [2023-10-26 18:17:36,079] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxr2qhw.csv
# [2023-10-26 18:17:36,101] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyb420b.csv
# [2023-10-26 18:17:36,123] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyb46wu.csv
# [2023-10-26 18:17:36,148] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwzfw1h.csv
# [2023-10-26 18:17:36,171] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwzfuxh.csv
# [2023-10-26 18:17:36,194] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwztx2q.csv
# [2023-10-26 18:17:36,216] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwzy28r.csv
# [2023-10-26 18:17:36,240] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwzz7d1.csv
# [2023-10-26 18:17:36,266] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwzxzv3.csv
# [2023-10-26 18:17:36,292] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtz/kxtz9m0rv.csv
# [2023-10-26 18:17:36,318] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtz/kxtz9w2c1.csv
# [2023-10-26 18:17:36,346] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtw839zp.csv
# [2023-10-26 18:17:36,368] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtw/kxtwckc6n.csv
# [2023-10-26 18:17:36,390] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtr/kxtrxbw0f.csv
# [2023-10-26 18:17:36,412] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxb6s0c.csv
# [2023-10-26 18:17:36,441] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxb7jh6.csv
# [2023-10-26 18:17:36,464] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxbsdvd.csv
# [2023-10-26 18:17:36,490] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxbykv9.csv
# [2023-10-26 18:17:36,514] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxcnzem.csv
# [2023-10-26 18:17:36,538] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxv8/kxv8105wu.csv
# [2023-10-26 18:17:36,562] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxv8/kxv811mwz.csv
# [2023-10-26 18:17:36,592] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxr3jm9.csv
# [2023-10-26 18:17:36,616] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtx7svxz.csv
# [2023-10-26 18:17:36,644] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtx7x39v.csv
# [2023-10-26 18:17:36,686] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxubtkj.csv
# [2023-10-26 18:17:36,715] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxy1pz8.csv
# [2023-10-26 18:17:36,743] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxg43vp.csv
# [2023-10-26 18:17:36,769] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxtx/kxtxvjxkm.csv
# [2023-10-26 18:17:36,793] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxv8/kxv8p5904.csv
# [2023-10-26 18:17:36,825] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxv8/kxv8nj6mg.csv
# [2023-10-26 18:17:36,855] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxv8/kxv86904k.csv
# [2023-10-26 18:17:36,890] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty7zn3s.csv
# [2023-10-26 18:17:36,913] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtykpkd2.csv
# [2023-10-26 18:17:36,935] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty7p7yc.csv
# [2023-10-26 18:17:36,964] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxty7zgfc.csv
# [2023-10-26 18:17:36,994] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtys027m.csv
# [2023-10-26 18:17:37,017] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyeb7te.csv
# [2023-10-26 18:17:37,038] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyeczer.csv
# [2023-10-26 18:17:37,059] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyehfvf.csv
# [2023-10-26 18:17:37,083] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyem82r.csv
# [2023-10-26 18:17:37,106] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyenqcd.csv
# [2023-10-26 18:17:37,129] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtys300n.csv
# [2023-10-26 18:17:37,151] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtysejk7.csv
# [2023-10-26 18:17:37,178] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtys7hnp.csv
# [2023-10-26 18:17:37,202] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyskuft.csv
# [2023-10-26 18:17:37,226] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtysnrxn.csv
# [2023-10-26 18:17:37,247] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtysx57k.csv
# [2023-10-26 18:17:37,270] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyu24th.csv
# [2023-10-26 18:17:37,291] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyubuht.csv
# [2023-10-26 18:17:37,314] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyu930q.csv
# [2023-10-26 18:17:37,336] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyucmtd.csv
# [2023-10-26 18:17:37,356] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyeq9ys.csv
# [2023-10-26 18:17:37,378] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtysp6wn.csv
# [2023-10-26 18:17:37,402] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyezks0.csv
# [2023-10-26 18:17:37,422] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyertmh.csv
# [2023-10-26 18:17:37,445] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyg2w05.csv
# [2023-10-26 18:17:37,472] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyg0x9n.csv
# [2023-10-26 18:17:37,496] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyg0tx8.csv
# [2023-10-26 18:17:37,523] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyg2yct.csv
# [2023-10-26 18:17:37,543] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyg34d6.csv
# [2023-10-26 18:17:37,567] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtygcw4g.csv
# [2023-10-26 18:17:37,597] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyv3qjb.csv
# [2023-10-26 18:17:37,622] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyv37p3.csv
# [2023-10-26 18:17:37,647] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyv38wp.csv
# [2023-10-26 18:17:37,668] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyv18x3.csv
# [2023-10-26 18:17:37,697] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyv4p6c.csv
# [2023-10-26 18:17:37,719] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyu6d58.csv
# [2023-10-26 18:17:37,743] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyv4y1t.csv
# [2023-10-26 18:17:37,768] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyv56gs.csv
# [2023-10-26 18:17:37,791] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyuunxj.csv
# [2023-10-26 18:17:37,817] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxty/kxtyuu8zc.csv
# ...
# [2023-10-26 18:19:40,784] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9m07y.csv
# [2023-10-26 18:19:40,808] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9jpmc.csv
# [2023-10-26 18:19:40,831] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9j4w1.csv
# [2023-10-26 18:19:40,855] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9j67y.csv
# [2023-10-26 18:19:40,881] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9jdu7.csv
# [2023-10-26 18:19:40,906] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9nz6b.csv
# [2023-10-26 18:19:40,926] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc0ru7.csv
# [2023-10-26 18:19:40,946] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyudscwy.csv
# [2023-10-26 18:19:40,966] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyudm6ht.csv
# [2023-10-26 18:19:40,991] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyudjkwt.csv
# [2023-10-26 18:19:41,013] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyudj8cu.csv
# [2023-10-26 18:19:41,035] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyudjc62.csv
# [2023-10-26 18:19:41,061] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9vgxh.csv
# [2023-10-26 18:19:41,087] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9y4gf.csv
# [2023-10-26 18:19:41,110] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyudq6yn.csv
# [2023-10-26 18:19:41,138] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyudnkwd.csv
# [2023-10-26 18:19:41,159] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyudqf5j.csv
# [2023-10-26 18:19:41,187] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9kufg.csv
# [2023-10-26 18:19:41,206] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9m4dt.csv
# [2023-10-26 18:19:41,226] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9whqf.csv
# [2023-10-26 18:19:41,251] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9qmrd.csv
# [2023-10-26 18:19:41,272] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9xhbu.csv
# [2023-10-26 18:19:41,298] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9rsus.csv
# [2023-10-26 18:19:41,327] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu9xfzv.csv
# [2023-10-26 18:19:41,349] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc811j.csv
# [2023-10-26 18:19:41,374] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc2p7t.csv
# [2023-10-26 18:19:41,398] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc2jqk.csv
# [2023-10-26 18:19:41,418] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezvf45.csv
# [2023-10-26 18:19:41,442] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezy4yf.csv
# [2023-10-26 18:19:41,465] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezy1xy.csv
# [2023-10-26 18:19:41,489] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezwr64.csv
# [2023-10-26 18:19:41,511] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezy6hb.csv
# [2023-10-26 18:19:41,533] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezyf6p.csv
# [2023-10-26 18:19:41,586] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezrqt6.csv
# [2023-10-26 18:19:41,610] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezrw90.csv
# [2023-10-26 18:19:41,631] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxye/kxyezz8sy.csv
# [2023-10-26 18:19:41,651] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspb4bj.csv
# [2023-10-26 18:19:41,677] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp86f4.csv
# [2023-10-26 18:19:41,700] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspb9z9.csv
# [2023-10-26 18:19:41,722] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspbceg.csv
# [2023-10-26 18:19:41,744] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp2yez.csv
# [2023-10-26 18:19:41,769] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp8vye.csv
# [2023-10-26 18:19:41,787] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspc4fq.csv
# [2023-10-26 18:19:41,807] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspc0k1.csv
# [2023-10-26 18:19:41,827] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp9nmx.csv
# [2023-10-26 18:19:41,849] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp3njr.csv
# [2023-10-26 18:19:41,874] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp3rw0.csv
# [2023-10-26 18:19:41,895] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspc94k.csv
# [2023-10-26 18:19:41,920] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp9wfz.csv
# [2023-10-26 18:19:41,941] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspcfm7.csv
# [2023-10-26 18:19:41,963] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp3ym0.csv
# [2023-10-26 18:19:41,989] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp9ymu.csv
# [2023-10-26 18:19:42,017] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp9uqs.csv
# [2023-10-26 18:19:42,040] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspde0c.csv
# [2023-10-26 18:19:42,066] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspdyft.csv
# [2023-10-26 18:19:42,092] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspdusk.csv
# [2023-10-26 18:19:42,116] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspe1bh.csv
# [2023-10-26 18:19:42,141] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspu3g7.csv
# [2023-10-26 18:19:42,161] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspsrw2.csv
# [2023-10-26 18:19:42,184] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspudvq.csv
# [2023-10-26 18:19:42,207] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspv01y.csv
# [2023-10-26 18:19:42,230] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysptwzq.csv
# [2023-10-26 18:19:42,254] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspy2q2.csv
# [2023-10-26 18:19:42,276] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspqz2t.csv
# [2023-10-26 18:19:42,300] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspzcz0.csv
# [2023-10-26 18:19:42,321] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxyspzbxu.csv
# [2023-10-26 18:19:42,346] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysr8nhy.csv
# [2023-10-26 18:19:42,368] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp2h25.csv
# [2023-10-26 18:19:42,393] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp250e.csv
# [2023-10-26 18:19:42,419] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp2kdz.csv
# [2023-10-26 18:19:42,444] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp22ws.csv
# [2023-10-26 18:19:42,471] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp28q5.csv
# [2023-10-26 18:19:42,493] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp3hth.csv
# [2023-10-26 18:19:42,516] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp3s6w.csv
# [2023-10-26 18:19:42,541] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp47ru.csv
# [2023-10-26 18:19:42,562] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysp696s.csv
# [2023-10-26 18:19:42,585] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysr2rjq.csv
# [2023-10-26 18:19:42,608] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysr8bhx.csv
# [2023-10-26 18:19:42,630] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysr93xv.csv
# [2023-10-26 18:19:42,653] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysr96xb.csv
# [2023-10-26 18:19:42,677] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysru7qk.csv
# [2023-10-26 18:19:42,701] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysry16j.csv
# [2023-10-26 18:19:42,721] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysrwpwt.csv
# [2023-10-26 18:19:42,746] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxys/kxysrxp3u.csv
# [2023-10-26 18:19:42,770] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc0mrb.csv
# [2023-10-26 18:19:42,793] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc1z3f.csv
# [2023-10-26 18:19:42,815] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc4peh.csv
# [2023-10-26 18:19:42,835] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyubf68h.csv
# [2023-10-26 18:19:42,857] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyubf6y6.csv
# [2023-10-26 18:19:42,882] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyubf3zy.csv
# [2023-10-26 18:19:42,928] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyubf8cg.csv
# [2023-10-26 18:19:42,953] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc59fv.csv
# [2023-10-26 18:19:42,975] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyubgxzd.csv
# [2023-10-26 18:19:43,003] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyuc7bjj.csv
# [2023-10-26 18:19:43,024] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu8dw1p.csv
# [2023-10-26 18:19:43,045] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu8dsgj.csv
# [2023-10-26 18:19:43,067] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu86u0m.csv
# [2023-10-26 18:19:43,090] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu8e188.csv
# [2023-10-26 18:19:43,113] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyubdwt2.csv
# [2023-10-26 18:19:43,138] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy291m0.csv
# [2023-10-26 18:19:43,165] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy29fyw.csv
# [2023-10-26 18:19:43,189] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2dqcu.csv
# [2023-10-26 18:19:43,218] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2dd9n.csv
# [2023-10-26 18:19:43,244] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2dw53.csv
# [2023-10-26 18:19:43,268] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu2n45z.csv
# [2023-10-26 18:19:43,294] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyu2r8bw.csv
# [2023-10-26 18:19:43,317] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyv/kxyv077mj.csv
# [2023-10-26 18:19:43,345] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyu/kxyucj5pk.csv
# [2023-10-26 18:19:43,376] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyv/kxyv16277.csv
# [2023-10-26 18:19:43,399] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyv/kxyv0ud2r.csv
# [2023-10-26 18:19:43,422] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyv/kxyv1pp9h.csv
# [2023-10-26 18:19:43,446] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2f3tc.csv
# [2023-10-26 18:19:43,474] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2fe4y.csv
# [2023-10-26 18:19:43,496] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2dz9k.csv
# [2023-10-26 18:19:43,521] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2gfsj.csv
# [2023-10-26 18:19:43,544] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2dfws.csv
# [2023-10-26 18:19:43,566] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2en2r.csv
# [2023-10-26 18:19:43,592] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2em3n.csv
# [2023-10-26 18:19:43,615] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2ekjg.csv
# [2023-10-26 18:19:43,640] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2eg9z.csv
# [2023-10-26 18:19:43,663] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2ezm5.csv
# [2023-10-26 18:19:43,689] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2snck.csv
# [2023-10-26 18:19:43,714] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2srw4.csv
# [2023-10-26 18:19:43,740] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2t2cd.csv
# [2023-10-26 18:19:43,767] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2mv39.csv
# [2023-10-26 18:19:43,791] {stack.py:273} INFO - Writing s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2mycv.csv

# %%
# Read a single csv file
timeseries =  pd.read_csv("s3://deafrica-waterbodies-dev/0-2-0/test_directory/kxyy/kxyy2mycv.csv")

# %%
timeseries
# Out:
#                    date  pc_wet  px_wet  area_wet_m2  pc_dry  px_dry  \
# 0  2003-01-17T07:49:46Z     NaN     NaN          NaN     NaN     NaN
#
#    area_dry_m2  pc_invalid  px_invalid  area_invalid_m2
# 0          NaN       100.0        30.0          27000.0
